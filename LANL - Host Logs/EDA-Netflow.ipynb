# %%
#Reading data line by line
file = "/home/rk9cx/LANL/netflow_day-02.txt"
#reading data into a set
with open(file, "r") as ins:
    data = []
    for line in ins:
        data.append(line)
print(len(data))
# Out:
# 115949436

# %%
#Reading data line by line
file = "/home/rk9cx/LANL/netflow_day-02.txt"
#reading data into a set
with open(file, "r") as ins:
    data = []
    prev_lis = []
    i = 1
    for line in ins:
        lis = line.split(",")
        if lis[2:7] != set(lis[2:7]).intersection(prev_lis[2:7]):
            data.append(prev_lis)
        prev_lis= lis
        i = i +1
        if i % 1000000 == 0:
            print("Million iteration")
            print(len(data))
with open("file.txt", "w") as output:
    output.write(str(data))
# Out:
# Million iteration
# 999999
# Million iteration
# 1999999
# Million iteration
# 2999999
# Million iteration
# 3999999
# Million iteration
# 4999999
# Million iteration
# 5999999
# Million iteration
# 6999999
# Million iteration
# 7999999
# Million iteration
# 8999999
# Million iteration
# 9999999
# Million iteration
# 10999999
# Million iteration
# 11999999
# Million iteration
# 12999999
# Million iteration
# 13999999
# Million iteration
# 14999999
# Million iteration
# 15999999
# Million iteration
# 16999999
# Million iteration
# 17999999
# Million iteration
# 18999999
# Million iteration
# 19999999
# Million iteration
# 20999999
# Million iteration
# 21999999
# Million iteration
# 22999999
# Million iteration
# 23999999
# Million iteration
# 24999999
# Million iteration
# 25999999
# Million iteration
# 26999999
# Million iteration
# 27999999
# Million iteration
# 28999999
# Million iteration
# 29999999
# Million iteration
# 30999999
# Million iteration
# 31999999
# Million iteration
# 32999999
# Million iteration
# 33999999
# Million iteration
# 34999999
# Million iteration
# 35999999
# Million iteration
# 36999999
# Million iteration
# 37999999
# Million iteration
# 38999999
# Million iteration
# 39999999
# Million iteration
# 40999999
# Million iteration
# 41999999
# Million iteration
# 42999999
# Million iteration
# 43999999
# Million iteration
# 44999999
# Million iteration
# 45999999
# Million iteration
# 46999999
# Million iteration
# 47999999
# Million iteration
# 48999999
# Million iteration
# 49999999
# Million iteration
# 50999999
# Million iteration
# 51999999
# Million iteration
# 52999999
# Million iteration
# 53999999
# Million iteration
# 54999999
# Million iteration
# 55999999
# Million iteration
# 56999999
# Million iteration
# 57999999
# Million iteration
# 58999999

# %% [markdown]
# df = pd.DataFrame.from_records(data, columns = header)
#
# df.drop_duplicates(subset=['Time', 'SrcDevice', 'DstDevice', 'Protocol', 'SrcPort', 'DstPort'], keep='last')
#
# dsts = df.loc[:,["Time","DstDevice"]]
#
# np.savetxt('Time-DstDevice.txt', dsts.values, fmt='%d,%d,', delimiter=",", header="Time,Duration,")

# %%
sample[1].split(",")[2:7]
# Out:
# ['Comp450942', 'Comp829338', '6', 'Port03137', '445']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e3f5d1236b73> in <module>()
# ----> 1 prev_lis
#
# NameError: name 'prev_lis' is not defined

# %%
def chunker(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

# %%
import os 
import pandas as pd
os.chdir("/home/rk9cx/")
df = pd.read_csv("singular.csv", index_col=False)
# Out:
# /apps/software/standard/core/anaconda3/5.2.0/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9,10,11,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.tail()
# Out:
#         Unnamed: 0    Time  EventID     LogHost  LogonType  \
# 249540      249540  172797     4625  Comp337732        3.0
# 249541      249541  172797     4634  Comp337732        3.0
# 249542      249542  172798     4634  Comp337732        3.0
# 249543      249543  172798     4634  Comp337732        3.0
# 249544      249544  172799     4634  Comp337732        3.0
#
#        LogonTypeDescription    UserName DomainName     LogonID  \
# 249540              Network  User249909  Domain001         NaN
# 249541              Network  User249909  Domain001  0x2a7f1f62
# 249542              Network  User988944  Domain001  0x2a7e86a7
# 249543              Network  User816098  Domain001  0x2a7e8e88
# 249544              Network  User096590  Domain001  0x2a7e8e63
#
#        SubjectUserName       ...       Status Source ServiceName Destination  \
# 249540             NaN       ...          NaN    NaN         NaN         NaN
# 249541             NaN       ...          NaN    NaN         NaN         NaN
# 249542             NaN       ...          NaN    NaN         NaN         NaN
# 249543             NaN       ...          NaN    NaN         NaN         NaN
# 249544             NaN       ...          NaN    NaN         NaN         NaN
#
#         AuthenticationPackage                   FailureReason ProcessName  \
# 249540               Kerberos  An Error occured during Logon.         NaN
# 249541                    NaN                             NaN         NaN
# 249542                    NaN                             NaN         NaN
# 249543                    NaN                             NaN         NaN
# 249544                    NaN                             NaN         NaN
#
#        ProcessID ParentProcessName ParentProcessID
# 249540       NaN               NaN             NaN
# 249541       NaN               NaN             NaN
# 249542       NaN               NaN             NaN
# 249543       NaN               NaN             NaN
# 249544       NaN               NaN             NaN
#
# [5 rows x 22 columns]
